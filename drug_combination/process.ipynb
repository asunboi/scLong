# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import normalize

# %%
# Test intersect genes

gene_list_scfm=[]
with open('/data1/ruiyi/scfm/selected_genes_27k.txt') as f:
    for l in f.readlines():
        gene_list_scfm.append(str(l.strip()))
len(gene_list_scfm)

gene_list_deepdds=[]
with open('data/independent_set/independent_cell_features_954.csv') as f:
    for l in f.readlines():
        l=l.strip().split(',')
        #print(l)
        break
gene_list_deepdds=l[1:]
len(gene_list_deepdds)

cnt=0
for gene in gene_list_deepdds:
    if gene in gene_list_scfm:cnt+=1
cnt
# Out:
# 954

# %%
deepdds_scfm_output=np.load('/data1/ruiyi/deepdds/deepdds_ind_scfm1227_output.npy')
deepdds_scfm_output.shape

# %%
deepdds_scfm_output_processed=np.zeros((deepdds_scfm_output.shape[0],len(gene_list_deepdds),deepdds_scfm_output.shape[-1]))
gene_deepdds2idx={v:k for k,v in enumerate(gene_list_deepdds)}
for k,v in enumerate(gene_list_scfm):
    if v in gene_deepdds2idx:
        idx=gene_deepdds2idx[v]
        deepdds_scfm_output_processed[:,idx,:]=deepdds_scfm_output[:,k,:]
deepdds_scfm_output_processed.shape
# Out:
# (1019, 954, 200)

# %%
np.save('/data1/ruiyi/deepdds/deepdds_ind_scfm1227_output_processd.npy', deepdds_scfm_output_processed)

# %%
cell_list_deepdds=[]
with open('data/independent_set/independent_cell_features_954.csv') as f:
    for l in f.readlines():
        l=l.strip().split(',')
        cell_list_deepdds.append(l[0])
cell_list_deepdds=cell_list_deepdds[2:]
cell_list_deepdds,len(cell_list_deepdds)
# Out:
# (['X22RV1_PROSTATE',
#   'X2313287_STOMACH',
#   'X253JBV_URINARY_TRACT',
#   'X253J_URINARY_TRACT',
#   'X42MGBA_CENTRAL_NERVOUS_SYSTEM',
#   'X5637_URINARY_TRACT',
#   'X59M_OVARY',
#   'X639V_URINARY_TRACT',
#   'X647V_URINARY_TRACT',
#   'X697_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE',
#   'X769P_KIDNEY',
#   'X786O_KIDNEY',
#   'X8305C_THYROID',
#   'X8505C_THYROID',
#   'X8MGBA_CENTRAL_NERVOUS_SYSTEM',
#   'A101D_SKIN',
#   'A1207_CENTRAL_NERVOUS_SYSTEM',
#   'A172_CENTRAL_NERVOUS_SYSTEM',
#   'A204_SOFT_TISSUE',
#   'A2058_SKIN',
#   'A253_SALIVARY_GLAND',
#   'A2780_OVARY',
#   'A375_SKIN',
#   'A3KAW_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE',
#   'A427_LUNG',
#   'A498_KIDNEY',
#   'A4FUK_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE',
#   'A549_LUNG',
#   'A673_BONE',
#   'A704_KIDNEY',
#   'ABC1_LUNG',
#   'ACCMESO1_PLEURA',
#   'ACHN_KIDNEY',
#   'AGS_STOMACH',
#   'ALLSIL_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE',
#   'AM38_CENTRAL_NERVOUS_SYSTEM',
#   'AML193_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE',
# ...

# %%
cell2embed={cell_list_deepdds[i].split('_')[0]:deepdds_scfm_output_processed[i] for i in range(len(cell_list_deepdds))}
np.save('/data1/ruiyi/deepdds/deepddsindcell2scfm1227embed.npy', cell2embed)
